# %%
print(1+1)
# Out:
# 2

# %%
age=int(input("Enter your age: "))
if age>=18:
    print("You are an adult.")
elif age<0:
    print("Invalid age.")
elif age<18:
    print("You are a minor.")
else:
    print(f"Error.{age}")
# Out:
# You are a minor.

# %%
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
numbers = (1, 2, 3, 4, 5,"hello", 6.7)
for number in numbers:
    print(number)
print(type(numbers))
# Out:
# 1
# 2
# 3
# 4
# 5
# hello
# 6.7
# <class 'tuple'>

# %%
class car:
    pass

a=car()
b=car()
print(type(car))
# Out:
# <class 'type'>

# %%
print(a)
print(b)
# Out:
# <__main__.car object at 0x1043fcd70>
# <__main__.car object at 0x104244cd0>

# %%
### Instance Variable
a.windowes=3
print(a.windowes)
# Out:
# 3

# %%
tata=car()
tata.windowes=4
print(tata.windowes)
# Out:
# 4

# %%
class car:
    def __init__(self,windowes):
        self.windowes=windowes
tata=car(windowes=4)
print(tata.windowes)
# Out:
# 4

# %%
class dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

d=dog("name=tommy",age=5)
print(d.name)
print(d.age)
# Out:
# name=tommy
# 5

# %%
d=dog(name="tommy",age=5)
print(d.name)
print(d.age)
# Out:
# tommy
# 5

# %%
class dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
            print("Woof!")
            print(f"{self.name} is barking.")

dog1=dog(name="tommy",age=5)
dog1.bark()
dog2=dog(name="buddy",age=3)
dog2.bark()
# Out:
# Woof!
# tommy is barking.
# Woof!
# buddy is barking.

# %%
###modeling a bank account
class BankAccount:
    def __init__(self,account_number,account_holder,balance=0):
        self.account_number=account_number
        self.account_holder=account_holder
        self.balance=balance

    def deposit(self,amount):
        if amount>0:
            self.balance+=amount
            print(f"Deposited {amount}. New balance: {self.balance}")
        else:
            print("Invalid deposit amount.")

    def withdraw(self,amount):
        if amount>0 and amount<=self.balance:
            self.balance-=amount
            print(f"Withdrew {amount}. New balance: {self.balance}")
        else:
            print("Invalid withdrawal amount or insufficient funds.")

# %%
bank_account=BankAccount(account_number="123456789",account_holder="John Doe")
bank_account.deposit(1000)
bank_account.withdraw(500)
bank_account.withdraw(600)
# Out:
# Deposited 1000. New balance: 1000
# Withdrew 500. New balance: 500
# Invalid withdrawal amount or insufficient funds.

# %%
import numpy as np
data=[np.random.standard_normal() for _ in range(10)]
data
print(type(data))
print(data)
# Out:
# <class 'list'>
# [0.12485020924732518, -0.7302182449061857, 1.63860327591054, -0.1670866455158197, 0.06797886072918183, -0.0021965384720646648, 0.726665520976753, 0.16797917121007075, -0.27382921730832693, 0.21836789558709707]

# %%
an  =10.000000
print(type(an))
# Out:
# <class 'float'>

# %%
b=[1,2,3,4,5]
print(type(b))
b.pop()
print(b)
b.append(6)
print(b)
b.copy()
print(b)
b.reverse()
print(b)
print(b[0])
b.clear()
# Out:
# <class 'list'>
# [1, 2, 3, 4]
# [1, 2, 3, 4, 6]
# [1, 2, 3, 4, 6]
# [6, 4, 3, 2, 1]
# 6

# %%
#### IGNORE ---
def square(x):
    for i in range(0,x):
       yield i**2
print(list(square(5)))
def generator():
    yield 1
    yield 2
# Out:
# [0, 1, 4, 9, 16]

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14*self.radius**2
circle=Circle(radius=5)
print(circle.area())
